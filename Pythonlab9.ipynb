# %%
dictionary_name = {
    "key1": "value1",
    "key2": "value2"
}

# %%
train = {
    "Train_Number":12951,
    "Train_Name":"Rajdhani Express",
    "Source":"Mumbai",
    "Destination":"Delhi",
    "Available_Seats":120
}

# %%
print("Train Information:")
print(train)

print("\nTrain Number:", train["Train_Number"])
print("Train Name:", train["Train_Name"])
print("Source:", train["Source"])
print("Destination:", train["Destination"])
print("Available Seats:", train["Available_Seats"])
# Out:
# Train Information:
# {'Train_Number': 12951, 'Train_Name': 'Rajdhani Express', 'Source': 'Mumbai', 'Destination': 'Delhi', 'Available_Seats': 120}
#
# Train Number: 12951
# Train Name: Rajdhani Express
# Source: Mumbai
# Destination: Delhi
# Available Seats: 120

# %%
train = {
    "Train_Number": 12951,
    "Train_Name": "Mumbai Rajdhani Express",
    "Available_Seats": 120
}

# %%
print(train)
# Out:
# {'Train_Number': 12951, 'Train_Name': 'Mumbai Rajdhani Express', 'Available_Seats': 120}

# %%
print("Train Name:", train["Train_Name"])
print("Available Seats:", train["Available_Seats"])
# Out:
# Train Name: Mumbai Rajdhani Express
# Available Seats: 120

# %%
train["Available_Seats"] = 95
print(train)
# Out:
# {'Train_Number': 12951, 'Train_Name': 'Mumbai Rajdhani Express', 'Available_Seats': 95}

# %%
train.update({"Platform":4})
print(train)
# Out:
# {'Train_Number': 12951, 'Train_Name': 'Mumbai Rajdhani Express', 'Available_Seats': 95, 'Platform': 4}

# %%
train.pop("Platform")
print(train)
# Out:
# {'Train_Number': 12951, 'Train_Name': 'Mumbai Rajdhani Express', 'Available_Seats': 95}

# %%
print("\nUpdated Train Record:")
print(train)
# Out:
# Updated Train Record:
# {'Train_Number': 12951, 'Train_Name': 'Mumbai Rajdhani Express', 'Available_Seats': 95}
