# %%
train_name="Rajdhani Express"
train_number = 12951
source_station="Mumbai"
destination_station="Delhi"
ticket_price= 2450.75

# %%
print("Welcome to Indian Railway Reservartion System")
print("Train_name:",train_name)
print("Train_number:",train_number)
print("Source_station:",source_station)
print("Destination_station:",destination_station)
# Out:
# Welcome to Indian Railway Reservartion System
# Train_name: Rajdhani Express
# Train_number: 12951
# Source_station: Mumbai
# Destination_station: Delhi

# %%
print(type(train_name))
print(type(train_number))
print(type(ticket_price))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>

# %%
passenger_name = "Rahul Sharma"
seat_number = "B2 - 45"
is_confirmed = "True"

# %%
ticket_price_integer=int(ticket_price)
print(type(ticket_price_integer))
# Out:
# <class 'int'>

# %%
train_number_string=str(train_number)
print(type(train_number_string))
# Out:
# <class 'str'>

# %%
passenger_name = "Rahul Sharma"
seat_number = "B2-45"
confirmation_status = "Confirmed"

# %%
type_cast=int(train_number)
print(type_cast)
# Out:
# 12951

# %%
sname="Anushka"
smarks=80
print("Student Name :   ", sname,"\n Student Marks :  ",smarks)
print(f"Student Name :  {sname}\n Student Marks:  {smarks}")
# Out:
# Student Name :    Anushka
#  Student Marks :   80
# Student Name :  Anushka
#  Student Marks:  80

# %%
sname = input("Enter your name:  ")
smarks=int(input("Enter your marks:  "))
new_smarks= smarks+5
print(sname)
print(new_smarks)
# Out:
# Enter your name:  Anushka
# Enter your marks:  70
# Anushka
# 75
